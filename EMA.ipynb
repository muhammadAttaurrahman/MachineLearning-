# %%
# !pip install mne

# %%
import numpy as np
import mne

# %%
# edf = mne.io.read_raw_edf('110001/13792_20180911_000000.edf')
# header = ','.join(edf.ch_names)
# np.savetxt('110001/hapt33.csv', edf.get_data().T, delimiter=',', header=header)

# %%
import pandas as pd

# %%
data_frame = pd.read_csv("hapt.csv")
data_frame.head()
# Out:
#    # AccX   AccY   AccZ  GyroX  GyroY  GyroZ
# 0   0.829 -0.302 -0.401   2.66   6.72  -5.81
# 1   0.831 -0.304 -0.411   1.75   6.79  -5.74
# 2   0.836 -0.310 -0.417   1.75   6.37  -5.74
# 3   0.839 -0.316 -0.424   2.38   5.67  -5.74
# 4   0.841 -0.314 -0.415   2.38   5.18  -5.39

# %%
data_frame.describe()
# Out:
#              # AccX          AccY          AccZ         GyroX         GyroY  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean  -2.731702e-01  9.567012e-02  1.634823e-01  4.080669e-01  6.050654e-01
# std    5.052474e-01  2.746789e-01  7.680417e-01  2.638998e+01  1.425287e+01
# min   -3.560000e+00 -1.860000e+00 -3.010000e+00 -1.480000e+03 -1.180000e+03
# 25%   -7.220000e-01 -1.030000e-01 -6.840000e-01 -4.200000e-01 -2.100000e-01
# 50%   -5.600000e-01  0.000000e+00  4.240000e-01  4.200000e-01  6.300000e-01
# 75%    2.810000e-01  2.560000e-01  9.680000e-01  1.190000e+00  1.400000e+00
# max    1.950000e+00  2.910000e+00  3.950000e+00  1.270000e+03  1.610000e+03
#
#               GyroZ
# count  1.048575e+06
# mean   5.865881e-01
# std    1.338379e+01
# min   -1.070000e+03
# 25%    2.800000e-01
# 50%    6.300000e-01
# 75%    9.800000e-01
# max    1.030000e+03

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   # AccX  1048575 non-null  float64
#  1   AccY    1048575 non-null  float64
#  2   AccZ    1048575 non-null  float64
#  3   GyroX   1048575 non-null  float64
#  4   GyroY   1048575 non-null  float64
#  5   GyroZ   1048575 non-null  float64
# dtypes: float64(6)
# memory usage: 48.0 MB

# %%
import matplotlib as plt
data_frame.hist(bins=50, figsize=(15,20))
# Out:
# array([[<AxesSubplot: title={'center': '# AccX'}>,
#         <AxesSubplot: title={'center': 'AccY'}>],
#        [<AxesSubplot: title={'center': 'AccZ'}>,
#         <AxesSubplot: title={'center': 'GyroX'}>],
#        [<AxesSubplot: title={'center': 'GyroY'}>,
#         <AxesSubplot: title={'center': 'GyroZ'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
attributes= ['# AccX', 'AccY', "AccZ", "GyroX","GyroY","GyroZ"]
scatter_matrix(data_frame[attributes], figsize=(15,20))
# Out:
# array([[<AxesSubplot: xlabel='# AccX', ylabel='# AccX'>,
#         <AxesSubplot: xlabel='AccY', ylabel='# AccX'>,
#         <AxesSubplot: xlabel='AccZ', ylabel='# AccX'>,
#         <AxesSubplot: xlabel='GyroX', ylabel='# AccX'>,
#         <AxesSubplot: xlabel='GyroY', ylabel='# AccX'>,
#         <AxesSubplot: xlabel='GyroZ', ylabel='# AccX'>],
#        [<AxesSubplot: xlabel='# AccX', ylabel='AccY'>,
#         <AxesSubplot: xlabel='AccY', ylabel='AccY'>,
#         <AxesSubplot: xlabel='AccZ', ylabel='AccY'>,
#         <AxesSubplot: xlabel='GyroX', ylabel='AccY'>,
#         <AxesSubplot: xlabel='GyroY', ylabel='AccY'>,
#         <AxesSubplot: xlabel='GyroZ', ylabel='AccY'>],
#        [<AxesSubplot: xlabel='# AccX', ylabel='AccZ'>,
#         <AxesSubplot: xlabel='AccY', ylabel='AccZ'>,
#         <AxesSubplot: xlabel='AccZ', ylabel='AccZ'>,
#         <AxesSubplot: xlabel='GyroX', ylabel='AccZ'>,
#         <AxesSubplot: xlabel='GyroY', ylabel='AccZ'>,
# ...

# %%
data_frame.plot(kind="scatter", x="# AccX", y="GyroX", alpha=0.8)
# Out:
# <AxesSubplot: xlabel='# AccX', ylabel='GyroX'>
